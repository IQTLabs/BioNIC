# %% [markdown]
# # Displaying the results of experiments
#
# ## Instructions
#
# 1. Run the driver.py file with all the models you want to explore (setting their configs).
# 2. Copy all the files dataframe_\*.csv to a directory you have access to, and set their paths in this code.
# 3. Specify the benchmark dataset all these models share (recall, you want to compare models on the same data) by setting this variable in the code. It must be the path that's specified in the csv.
# 3. Run the cell(s) below to generate graphs for each dataset, comparing performance of different models on the same dataset

# %%
import copy
download_dir = "/Users/kdobolyi/Downloads/"

# ####################################################################################################################

# what is the shared dataset that you built your model(s) on?
# note: this must match the 'dataset' column in your csv below; it is a relative path only
benchmark_kaggle_bowl = "kaggle_bowl"

# where are all the results you created using driver.py
dataframes_kaggle_bowl = ["dataframe_VggModelAllLayers_kaggle_bowl_blog1_20epochs_lr_001.csv",
            #"./dataframe_VggModelLowerLayers_kaggle_bowl_blog1_20epochs_lr_001.csv",
            #"./dataframe_ResNet18ModelLowerLayers_kaggle_bowl_blog1_20epochs_lr_001.csv",
            #"dataframe_ResNet18ModelAllLayers_kaggle_bowl_blog1_20epochs_lr_001.csv",
            #"./dataframe_CNNMiniModel_kaggle_bowl_blog1_20epochs_lr_001.csv",
            #"./dataframe_CNNModel_kaggle_bowl_blog1_20epochs_lr_001.csv",
             #"./dataframe_VggModelAllLayers_kaggle_bowl_center_crop.csv",
              #"./dataframe_VggModelAllLayers_kaggle_bowl_full_resize.csv",
              #"./dataframe_VggModelAllLayers_kaggle_bowl_half_resize.csv",
              #"./dataframe_VggModelAllLayers_kaggle_bowl_random_crop.csv",
              #"./dataframe_ResNet18ModelAllLayers_kaggle_bowl_otsu_thresh_sobel_20epochs_lr_001.csv",
              #"./dataframe_ResNet18ModelAllLayers_kaggle_bowl_mean_thresh_sobel_20epochs_lr_001.csv",
              #"./dataframe_ResNet18ModelAllLayers_kaggle_bowl_tophat_mean_thresh_20epochs_lr_001.csv",
              #"./dataframe_ResNet18ModelAllLayers_kaggle_bowl_tophat_otsu_thresh_20epochs_lr_001.csv",
              #"./dataframe_ResNet18ModelAllLayers_kaggle_bowl_erosion_20epochs_lr_001.csv",
              #"./dataframe_ResNet18ModelAllLayers_kaggle_bowl_clahe_20epochs_lr_001.csv",
              #"./dataframe_VggModelAllLayers_kaggle_bowl_LBP.csv",
            "dataframe_Vgg19ThreeChannelModelAllLayers_kaggle_bowl_withoutImageNet_20epochs_lr_001.csv",
            "dataframe_Vgg19ThreeChannelModelAllLayers_kaggle_bowl_withImageNet_20epochs_lr_001.csv",
            "dataframe_Vgg19ThreeChannelModelAllLayersCovid19_kaggle_bowl_withImageNet_20epochs_lr_001.csv",
            "dataframe_Vgg19ThreeChannelModelAllLayersCovid19_kaggle_bowl_withoutImageNet_20epochs_lr_001.csv",
            "dataframe_Vgg19OneChannelModelAllLayers_kaggle_bowl_withoutImageNet_20epochs_lr_001.csv",
            "dataframe_Vgg19OneChannelModelAllLayers_kaggle_bowl_withImageNet_20epochs_lr_001.csv",
            "dataframe_Vgg19OneChannelModelAllLayersCovid19_kaggle_bowl_withoutImageNet_20epochs_lr_001.csv",
            "dataframe_Vgg19OneChannelModelAllLayersCovid19_kaggle_bowl_withImageNet_20epochs_lr_001.csv",
            "dataframe_CNNGreyModelCovid19_kaggle_bowl__20epochs_lr_001.csv"
             ]
# what are the orderings of the models you want to display for this experiment?
order_kaggle_bowl_blog1_test = ['Vgg_all', 'Vgg_lower', 'ResNet_all', 'ResNet_lower', 'CNN_all', 'CNN_flat']
order_kaggle_bowl_blog1_holdout = ['Vgg_all', 'Vgg_all_vote', 'Vgg_lower', 'Vgg_lower_vote', 'ResNet_all', 'ResNet_all_vote', 'ResNet_lower', 'ResNet_lower_vote', 'CNN_all', 'CNN_all_vote', 'CNN_flat', 'CNN_flat_vote']
order_kaggle_bowl_blog2_test = ['ResNet_all', 'erode', 'sobel_otsu', 'sobel_mean', 'tophat_otsu', 'tophat_mean', 'clahe']
order_kaggle_bowl_blog2_holdout = ['ResNet_all', 'ResNet_all_vote', 'erode', 'erode_vote', 'sobel_otsu', 'sobel_otsu_vote', 'sobel_mean', 'sobel_mean_vote', 'tophat_otsu', 'tophat_otsu_vote', 'tophat_mean', 'tophat_mean_vote', 'clahe', 'clahe_vote']
order_kaggle_bowl_blog4_test = ['Vgg_lower', 'Vgg16BN_pretrained', 'Vgg19BN_grey_covid', 'Vgg19BN_pretrained']
order_kaggle_bowl_blog4_holdout = ['Vgg_lower', 'Vgg_lower_vote', 'Vgg16BN_pretrained', 'Vgg16BN_pretrained_vote', 'Vgg19BN_grey_covid', 'Vgg19BN_grey_covid_vote', 'Vgg19BN_pretrained', 'Vgg19BN_pretrained_vote']
order_kaggle_bowl_blog5_test = copy.deepcopy(order_kaggle_bowl_blog1_test)
order_kaggle_bowl_blog5_test.extend(order_kaggle_bowl_blog4_test[1:])
order_kaggle_bowl_blog5_holdout = copy.deepcopy(order_kaggle_bowl_blog1_holdout)
order_kaggle_bowl_blog5_holdout.extend(order_kaggle_bowl_blog4_holdout[2:])
order_kaggle_bowl_blog6_test = ['Vgg_all', 'Vgg19Color_COVID19_pretrained', 
 'Vgg19Color_COVID19', 'Vgg19Color_pretrained',
 'Vgg19Color', 'Vgg19GreyCOVID19_pretrained',
 'Vgg19GreyCOVID19', 'CNNGrey_COVID19']
order_kaggle_bowl_blog6_holdout = ['Vgg_all', 'Vgg_all_vote', 'Vgg19Color_COVID19_pretrained', 'Vgg19Color_COVID19_pretrained_vote', 
 'Vgg19Color_COVID19', 'Vgg19Color_COVID19_vote', 'Vgg19Color_pretrained', 'Vgg19Color_pretrained_vote',
 'Vgg19Color', 'Vgg19Color_vote', 'Vgg19GreyCOVID19_pretrained', 'Vgg19GreyCOVID19_pretrained_vote',
 'Vgg19GreyCOVID19', 'Vgg19GreyCOVID19_vote', 'CNNGrey_COVID19', 'CNNGrey_COVID19_vote']
# ####################################################################################################################

benchmark_malaria = "malaria_cell_images"
dataframes_malaria = [
    #"./dataframe_CNNMiniModel_malaria_cell_images_blog1_30epochs_lr_001.csv",
    #"./dataframe_CNNModel_malaria_cell_images_blog1_30epochs_lr_001.csv",
    #"./dataframe_ResNet18ModelAllLayers_malaria_cell_images_blog1_30epochs_lr_001.csv",
    #"./dataframe_ResNet18ModelLowerLayers_malaria_cell_images_blog1_30epochs_lr_001.csv",
    "./dataframe_VggModelAllLayers_malaria_cell_images_blog1_30epochs_lr_001.csv",
    #"./dataframe_VggModelLowerLayers_malaria_cell_images_blog1_30epochs_lr_001.csv",
    #"./dataframe_ResNet18ModelAllLayers_malaria_cell_images_blog1_20e.csv",
    #"./dataframe_CNNModel_malaria_cell_images_centercrop.csv",
    #"./dataframe_CNNModel_malaria_cell_images_resize.csv",
    #"./dataframe_CNNModel_malaria_cell_images_tophat_mean_thresh_30epochs_lr_001.csv",
    #"./dataframe_CNNModel_malaria_cell_images_mean_thresh_sobel_30epochs_lr_001.csv",
    #"./dataframe_CNNModel_malaria_cell_images_otsu_thresh_sobel_30epochs_lr_001.csv",
    #"./dataframe_CNNModel_malaria_cell_images_tophat_otsu_thresh_30epochs_lr_001.csv",
    #"./dataframe_CNNModel_malaria_cell_images_erode_30epochs_lr_001.csv",
    #"./dataframe_CNNModel_malaria_cell_images_clahe_30epochs_lr_001.csv",
    #"./dataframe_CNNModel_malaria_cell_images_subset_500_blog1_venn.csv",
    #"./dataframe_CNNModel_malaria_cell_images_LBP.csv",
    "./dataframe_Vgg19OneChannelModelAllLayers_malaria_cell_images_withoutImageNet_20epochs_lr1e-05.csv",
    "./dataframe_Vgg19OneChannelModelAllLayers_malaria_cell_images_withImageNet_20epochs_lr1e-05.csv",
    "./dataframe_Vgg19OneChannelModelAllLayersCovid19_malaria_cell_images_withImageNet_20epochs_lr_001.csv",
    "./dataframe_Vgg19OneChannelModelAllLayersCovid19_malaria_cell_images_withoutImageNet_20epochs_lr_001.csv",
    "./dataframe_Vgg19ThreeChannelModelAllLayers_malaria_cell_images_withoutImageNet_20epochs_lr_001.csv",
    "./dataframe_Vgg19ThreeChannelModelAllLayers_malaria_cell_images_withImageNet_20epochs_lr_001.csv",
    "./dataframe_Vgg19ThreeChannelModelAllLayersCovid19_malaria_cell_images_withImageNet_20epochs_lr_001.csv",
    "./dataframe_Vgg19ThreeChannelModelAllLayersCovid19_malaria_cell_images_withoutImageNet_20epochs_lr_001.csv",
    "./dataframe_CNNGreyModelCovid19_malaria_cell_images__20epochs_lr1e-05.csv"
             ]
order_malaria_blog1_test = ['Vgg_all', 'Vgg_lower', 'ResNet_all', 'ResNet_lower', 'CNN_all', 'CNN_flat']
order_malaria_blog1_holdout = ['Vgg_all', 'Vgg_all_vote', 'Vgg_lower', 'Vgg_lower_vote', 'ResNet_all', 'ResNet_all_vote', 'ResNet_lower', 'ResNet_lower_vote', 'CNN_all', 'CNN_all_vote', 'CNN_flat', 'CNN_flat_vote']
order_malaria_blog2_test = ['CNN_all', 'erode', 'sobel_otsu', 'sobel_mean', 'tophat_otsu', 'tophat_mean', 'clahe']
order_malaria_blog2_holdout = ['CNN_all', 'CNN_all_vote', 'erode', 'erode_vote', 'sobel_otsu', 'sobel_otsu_vote', 'sobel_mean', 'sobel_mean_vote', 'tophat_otsu', 'tophat_otsu_vote', 'tophat_mean', 'tophat_mean_vote', 'clahe', 'clahe_vote']
order_malaria_blog4_test = ['CNN_all', 'Vgg16BN_pretrained', 'Vgg19BN_grey_covid', 'Vgg19BN_pretrained']
order_malaria_blog4_holdout = ['CNN_all', 'CNN_all_vote', 'Vgg16BN_pretrained', 'Vgg16BN_pretrained_vote', 'Vgg19BN_grey_covid', 'Vgg19BN_grey_covid_vote', 'Vgg19BN_pretrained', 'Vgg19BN_pretrained_vote']
order_malaria_blog5_test = copy.deepcopy(order_malaria_blog1_test)
order_malaria_blog5_test.extend(order_malaria_blog4_test[1:])
order_malaria_blog5_holdout = copy.deepcopy(order_malaria_blog1_holdout)
order_malaria_blog5_holdout.extend(order_malaria_blog4_holdout[2:])

# ####################################################################################################################

benchmark_blood_slide = "blood_WBC"
dataframes_blood_slide = [
    #"./dataframe_CNNMiniModel_blood_WBC_blog1_30epochs_lr_01.csv",
    "./dataframe_CNNModel_blood_WBC_blog1_30epochs_lr_01.csv",
    #"./dataframe_ResNet18ModelAllLayers_blood_WBC_blog1_30epochs_lr_01.csv",
    #"./dataframe_ResNet18ModelLowerLayers_blood_WBC_blog1_30epochs_lr_01.csv",
    "./dataframe_VggModelAllLayers_blood_WBC_blog1_30epochs_lr_01.csv",
    #"./dataframe_VggModelLowerLayers_blood_WBC_blog1_30epochs_lr_01.csv",
    #"./dataframe_CNNModel_blood_WBC_LBP.csv",
    #"./dataframe_CNNModel_blood_WBC_mean_thresh_sobel.csv",
    #"./dataframe_CNNModel_blood_WBC_otsu_thresh_sobel.csv",
    #"./dataframe_CNNModel_blood_WBC_tophat_otsu_thresh.csv",
    #"./dataframe_CNNModel_blood_WBC_tophat_mean_thresh.csv",
    #"./dataframe_CNNModel_blood_WBC_erode.csv",
    #"./dataframe_CNNModel_blood_WBC_clahe.csv",
    "./dataframe_Vgg19OneChannelModelAllLayers_blood_WBC_withoutImageNet_20epochs_lr1e-05.csv",
    "./dataframe_Vgg19OneChannelModelAllLayers_blood_WBC_withImageNet_20epochs_lr1e-05.csv",
    "./dataframe_Vgg19OneChannelModelAllLayersCovid19_blood_WBC_withImageNet_20epochs_lr1e-05.csv",
    "./dataframe_Vgg19OneChannelModelAllLayersCovid19_blood_WBC_withoutImageNet_20epochs_lr1e-05.csv",
    "./dataframe_Vgg19ThreeChannelModelAllLayers_blood_WBC_withoutImageNet_20epochs_lr_001.csv",
    "./dataframe_Vgg19ThreeChannelModelAllLayers_blood_WBC_withImageNet_20epochs_lr_001.csv",
    "./dataframe_Vgg19ThreeChannelModelAllLayersCovid19_blood_WBC_withImageNet_20epochs_lr_001.csv",
    "./dataframe_Vgg19ThreeChannelModelAllLayersCovid19_blood_WBC_withoutImageNet_20epochs_lr_001.csv",
    "./dataframe_CNNGreyModelCovid19_blood_WBC__20epochs_lr1e-05.csv"
]
order_blood_slide_blog1_test = ['Vgg_all', 'Vgg_lower', 'ResNet_all', 'ResNet_lower', 'CNN_all', 'CNN_flat']
order_blood_slide_blog1_holdout = ['Vgg_all', 'Vgg_all_vote', 'Vgg_lower', 'Vgg_lower_vote', 'ResNet_all', 'ResNet_all_vote', 'ResNet_lower', 'ResNet_lower_vote', 'CNN_all', 'CNN_all_vote', 'CNN_flat', 'CNN_flat_vote']
order_blood_slide_blog2_test = ['CNN_all', 'erode', 'sobel_otsu', 'sobel_mean', 'tophat_otsu', 'tophat_mean', 'clahe']
order_blood_slide_blog2_holdout = ['CNN_all', 'CNN_all_vote', 'erode', 'erode_vote', 'sobel_otsu', 'sobel_otsu_vote', 'sobel_mean', 'sobel_mean_vote', 'tophat_otsu', 'tophat_otsu_vote', 'tophat_mean', 'tophat_mean_vote', 'clahe', 'clahe_vote']
order_blood_slide_blog4_test = ['CNN_all', 'Vgg16BN_pretrained', 'Vgg19BN_grey_covid', 'Vgg19BN_pretrained']
order_blood_slide_blog4_holdout = ['CNN_all', 'CNN_all_vote', 'Vgg16BN_pretrained', 'Vgg16BN_pretrained_vote', 'Vgg19BN_grey_covid', 'Vgg19BN_grey_covid_vote', 'Vgg19BN_pretrained', 'Vgg19BN_pretrained_vote']
order_blood_slide_blog5_test = copy.deepcopy(order_blood_slide_blog1_test)
order_blood_slide_blog5_test.extend(order_blood_slide_blog4_test[1:])
order_blood_slide_blog5_holdout = copy.deepcopy(order_blood_slide_blog1_holdout)
order_blood_slide_blog5_holdout.extend(order_blood_slide_blog4_holdout[2:])

# ####################################################################################################################

benchmark_cat_images = "cat_images_border"
dataframes_cat_images = [
    #"./dataframe_CNNMiniModel_cat_images_border_blog1_30epochs_lr_001.csv",
    #"./dataframe_CNNModel_cat_images_border_blog1_30epochs_lr_001.csv",
    #"./dataframe_ResNet18ModelAllLayers_cat_images_border_blog1_30epochs_lr_001.csv",
    #"./dataframe_ResNet18ModelLowerLayers_cat_images_border_blog1_30epochs_lr_001.csv",
    #"./dataframe_VggModelLowerLayers_cat_images_border_blog1_30epochs_lr_001.csv",
    "./dataframe_VggModelAllLayers_cat_images_border_blog1_30epochs_lr_001.csv",
    #"./dataframe_CNNModel_cat_images_border_fullsize_30epochs_lr_001.csv",
    #"./dataframe_VggModelAllLayers_cat_images_border_LBP.csv",
    #"./dataframe_VggModelAllLayers_cat_images_border_mean_thresh_sobel_30epochs_lr_001.csv",
    #"./dataframe_VggModelAllLayers_cat_images_border_otsu_thresh_sobel_30epochs_lr_001.csv",
    #"./dataframe_VggModelAllLayers_cat_images_border_tophat_otsu_thresh_30epochs_lr_001.csv",
    #"./dataframe_VggModelAllLayers_cat_images_border_tophat_mean_thresh_30epochs_lr_001.csv",
    #"./dataframe_VggModelAllLayers_cat_images_border_clahe_30epochs_lr_001.csv",
    "./dataframe_Vgg19ThreeChannelModelAllLayers_cat_images_border_withoutImageNet_20epochs_lr1e-05.csv",
    "./dataframe_Vgg19ThreeChannelModelAllLayers_cat_images_border_withImageNet_20epochs_lr_001.csv",
    "./dataframe_Vgg19ThreeChannelModelAllLayersCovid19_cat_images_border_withImageNet_20epochs_lr1e-05.csv",
    "./dataframe_Vgg19ThreeChannelModelAllLayersCovid19_cat_images_border_withoutImageNet_20epochs_lr1e-05.csv",
    "./dataframe_Vgg19OneChannelModelAllLayers_cat_images_border_withoutImageNet_20epochs_lr1e-05.csv",
    "./dataframe_Vgg19OneChannelModelAllLayers_cat_images_border_withImageNet_20epochs_lr1e-05.csv",
    "./dataframe_Vgg19OneChannelModelAllLayersCovid19_cat_images_border_withImageNet_20epochs_lr1e-05.csv",
    "./dataframe_Vgg19OneChannelModelAllLayersCovid19_cat_images_border_withoutImageNet_20epochs_lr1e-05.csv",
    "./dataframe_CNNGreyModelCovid19_cat_images_border__20epochs_lr1e-05.csv"
]
order_cat_images_blog1_test = ['Vgg_all', 'Vgg_lower', 'ResNet_all', 'ResNet_lower', 'CNN_all', 'CNN_flat']
order_cat_images_blog1_holdout = ['Vgg_all', 'Vgg_all_vote', 'Vgg_lower', 'Vgg_lower_vote', 'ResNet_all', 'ResNet_all_vote', 'ResNet_lower', 'ResNet_lower_vote', 'CNN_all', 'CNN_all_vote', 'CNN_flat', 'CNN_flat_vote']
order_cat_images_blog2_test = ['Vgg_all', 'erode', 'sobel_otsu', 'sobel_mean', 'tophat_otsu', 'tophat_mean', 'clahe']
order_cat_images_blog2_holdout = ['Vgg_all', 'Vgg_all_vote', 'erode', 'erode_vote', 'sobel_otsu', 'sobel_otsu_vote', 'sobel_mean', 'sobel_mean_vote', 'tophat_otsu', 'tophat_otsu_vote', 'tophat_mean', 'tophat_mean_vote', 'clahe', 'clahe_vote']
order_cat_images_blog3_test = ['Vgg_all', 'CNN_all', 'CNN_large_image']
order_cat_images_blog3_holdout = ['Vgg_all', 'Vgg_all_vote', 'CNN_all', 'CNN_all_vote', 'CNN_large_image', 'CNN_large_image_vote']
order_cat_images_blog4_test = ['Vgg_all', 'Vgg16BN_pretrained', 'Vgg19BN_grey_covid', 'Vgg19BN_pretrained']
order_cat_images_blog4_holdout = ['Vgg_all', 'Vgg_all_vote', 'Vgg16BN_pretrained', 'Vgg16BN_pretrained_vote', 'Vgg19BN_grey_covid', 'Vgg19BN_grey_covid_vote', 'Vgg19BN_pretrained', 'Vgg19BN_pretrained_vote']
order_cat_images_blog5_test = copy.deepcopy(order_cat_images_blog1_test)
order_cat_images_blog5_test.extend(order_cat_images_blog4_test[1:])
order_cat_images_blog5_holdout = copy.deepcopy(order_cat_images_blog1_holdout)
order_cat_images_blog5_holdout.extend(order_cat_images_blog4_holdout[2:])

# ####################################################################################################################

benchmark_confocal_protein = 'labeled_confocal_protein'
dataframes_confocal_protein = [
    #"./dataframe_CNNMiniModel_labeled_confocal_protein_blog1_20epochs_lr_001.csv",
    #"./dataframe_CNNModel_labeled_confocal_protein_blog1_20epochs_lr_001.csv",
    #"./dataframe_ResNet18ModelAllLayers_labeled_confocal_protein_blog1_20epochs_lr_001.csv",
    "./dataframe_ResNet18ModelLowerLayers_labeled_confocal_protein_blog1_20epochs_lr_001.csv",
    "./dataframe_VggModelAllLayers_labeled_confocal_protein_blog1_20epochs_lr_001.csv",
    #"./dataframe_VggModelLowerLayers_labeled_confocal_protein_blog1_20epochs_lr_001.csv",
    #"./dataframe_CNNModel_labeled_confocal_protein_fullsize_20epochs_lr_001.csv",
    #"./dataframe_ResNet18ModelLowerLayers_labeled_confocal_protein_erode_20epochs_lr_001.csv",
    #"./dataframe_ResNet18ModelLowerLayers_labeled_confocal_protein_otsu_thresh_sobel_20epochs_lr_001.csv",
    #"./dataframe_ResNet18ModelLowerLayers_labeled_confocal_protein_mean_thresh_sobel_20epochs_lr_001.csv",
    #"./dataframe_ResNet18ModelLowerLayers_labeled_confocal_protein_tophat_mean_thresh_20epochs_lr_001.csv",
    #"./dataframe_ResNet18ModelLowerLayers_labeled_confocal_protein_tophat_otsu_thresh_20epochs_lr_001.csv",
    #"./dataframe_ResNet18ModelLowerLayers_labeled_confocal_protein_clahe_20epochs_lr_001.csv",
    #"./dataframe_CNNModel_labeled_confocal_protein_blog1_venn.csv",
    
    "./dataframe_Vgg19ThreeChannelModelAllLayers_labeled_confocal_protein_withoutImageNet_20epochs_lr1e-5.csv",
    "./dataframe_Vgg19ThreeChannelModelAllLayers_labeled_confocal_protein_withImageNet_20epochs_lr1e-5.csv",
    "./dataframe_Vgg19ThreeChannelModelAllLayersCovid19_labeled_confocal_protein_withImageNet_20epochs_lr1e-3.csv",
    "./dataframe_Vgg19ThreeChannelModelAllLayersCovid19_labeled_confocal_protein_withoutImageNet_20epochs_lr1e-3.csv",
    "./dataframe_Vgg19OneChannelModelAllLayers_labeled_confocal_protein_withoutImageNet_20epochs_lr1e-05.csv",
    "./dataframe_Vgg19OneChannelModelAllLayers_labeled_confocal_protein_withImageNet_20epochs_lr1e-05.csv",
    "./dataframe_Vgg19OneChannelModelAllLayersCovid19_labeled_confocal_protein_withImageNet_20epochs_lr1e-05.csv",
    "./dataframe_Vgg19OneChannelModelAllLayersCovid19_labeled_confocal_protein_withoutImageNet_20epochs_lr1e-05.csv",
    "./dataframe_CNNGreyModelCovid19_labeled_confocal_protein__20epochs_lr1e-05.csv"
]
order_confocal_protein_blog1_test = ['Vgg_all', 'Vgg_lower', 'ResNet_all', 'ResNet_lower', 'CNN_all', 'CNN_flat']
order_confocal_protein_blog1_holdout = ['Vgg_all', 'Vgg_all_vote', 'Vgg_lower', 'Vgg_lower_vote', 'ResNet_all', 'ResNet_all_vote', 'ResNet_lower', 'ResNet_lower_vote', 'CNN_all', 'CNN_all_vote', 'CNN_flat', 'CNN_flat_vote']
order_confocal_protein_blog2_test = ['ResNet_lower', 'erode', 'sobel_otsu', 'sobel_mean', 'tophat_otsu', 'tophat_mean', 'clahe']
order_confocal_protein_blog2_holdout = ['ResNet_lower', 'ResNet_lower_vote', 'erode', 'erode_vote', 'sobel_otsu', 'sobel_otsu_vote', 'sobel_mean', 'sobel_mean_vote', 'tophat_otsu', 'tophat_otsu_vote', 'tophat_mean', 'tophat_mean_vote', 'clahe', 'clahe_vote']
order_confocal_protein_blog3_test = ['ResNet_lower', 'CNN_all', 'CNN_large_image']
order_confocal_protein_blog3_holdout = ['ResNet_lower', 'ResNet_lower_vote', 'CNN_all', 'CNN_all_vote', 'CNN_large_image', 'CNN_large_image_vote']
order_confocal_protein_blog4_test = ['CNN_all', 'Vgg16BN_pretrained', 'Vgg19BN_grey_covid', 'Vgg19BN_pretrained']
order_confocal_protein_blog4_holdout = ['CNN_all', 'CNN_all_vote', 'Vgg16BN_pretrained', 'Vgg16BN_pretrained_vote', 'Vgg19BN_grey_covid', 'Vgg19BN_grey_covid_vote', 'Vgg19BN_pretrained', 'Vgg19BN_pretrained_vote']
order_confocal_protein_blog5_test = copy.deepcopy(order_confocal_protein_blog1_test)
order_confocal_protein_blog5_test.extend(order_confocal_protein_blog4_test[1:])
order_confocal_protein_blog5_holdout = copy.deepcopy(order_confocal_protein_blog1_holdout)
order_confocal_protein_blog5_holdout.extend(order_confocal_protein_blog4_holdout[2:])

# ####################################################################################################################

benchmark_CHO_images = 'CHO_images'
dataframes_CHO_images = [
    "./dataframe_CNNMiniModel_CHO_images_blog1_15epochs_lr_001.csv",
    "./dataframe_CNNModel_CHO_images_blog1_15epochs_lr_001.csv",
    "./dataframe_ResNet18ModelAllLayers_CHO_images_blog1_15epochs_lr_001.csv",
    "./dataframe_ResNet18ModelLowerLayers_CHO_images_blog1_15epochs_lr_001.csv",
    "./dataframe_VggModelAllLayers_CHO_images_blog1_15epochs_lr_001.csv",
    "./dataframe_VggModelLowerLayers_CHO_images_blog1_15epochs_lr_001.csv",
    #"./dataframe_ResNet18ModelAllLayers_CHO_images_blog1_20e.csv",
    #"./dataframe_VggModelLowerLayers_CHO_images_blog1_15epochs_lr_001.csv",
    "./dataframe_VggModelAllLayers_CHO_images_erode_15epochs_lr_001.csv",
    "./dataframe_VggModelAllLayers_CHO_images_mean_thresh_sobel_15epochs_lr_001.csv",
    "./dataframe_VggModelAllLayers_CHO_images_otsu_thresh_sobel_15epochs_lr_001.csv",
    "./dataframe_VggModelAllLayers_CHO_images_tophat_mean_thresh_15epochs_lr_001.csv",
    "./dataframe_VggModelAllLayers_CHO_images_tophat_otsu_thresh_15epochs_lr_001.csv",
    "./dataframe_VggModelAllLayers_CHO_images_clahe_15epochs_lr_001.csv",
    #"./dataframe_CNNModel_CHO_images_blog1_venn.csv",
    "./dataframe_Vgg19OneChannelModelAllLayersCovid19_CHO_images_withoutImageNet_20epochs_lr1e-3.csv",
    "./dataframe_Vgg19OneChannelModelAllLayersCovid19_CHO_images_withImageNet_20epochs_lr1e-3.csv",
    "./dataframe_Vgg19OneChannelModelAllLayers_CHO_images_withImageNet_20epochs_lr1e-3.csv",
    "./dataframe_Vgg19OneChannelModelAllLayers_CHO_images_withoutImageNet_20epochs_lr1e-3.csv",
    "./dataframe_Vgg19ThreeChannelModelAllLayersCovid19_CHO_images_withoutImageNet_20epochs_lr1e-3.csv",
    "./dataframe_Vgg19ThreeChannelModelAllLayersCovid19_CHO_images_withImageNet_15epochs_lr1e-3.csv",
    "./dataframe_Vgg19ThreeChannelModelAllLayers_CHO_images_withImageNet_15epochs_lr1e-3.csv",
    "./dataframe_Vgg19ThreeChannelModelAllLayers_CHO_images_withoutImageNet_15epochs_lr1e-3.csv",
    "dataframe_CNNGreyModelCovid19_CHO_images__15epochs_lr1e-4.csv"
]
order_CHO_images_blog1_test = ['Vgg_all', 'Vgg_lower', 'ResNet_all', 'ResNet_lower', 'CNN_all', 'CNN_flat']
order_CHO_images_blog1_holdout = ['Vgg_all', 'Vgg_all_vote', 'Vgg_lower', 'Vgg_lower_vote', 'ResNet_all', 'ResNet_all_vote', 'ResNet_lower', 'ResNet_lower_vote', 'CNN_all', 'CNN_all_vote', 'CNN_flat', 'CNN_flat_vote']
order_CHO_images_blog2_test = ['Vgg_all', 'erode', 'sobel_otsu', 'sobel_mean', 'tophat_otsu', 'tophat_mean', 'clahe']
order_CHO_images_blog2_holdout = ['Vgg_all', 'Vgg_all_vote', 'erode', 'erode_vote', 'sobel_otsu', 'sobel_otsu_vote', 'sobel_mean', 'sobel_mean_vote', 'tophat_otsu', 'tophat_otsu_vote', 'tophat_mean', 'tophat_mean_vote', 'clahe', 'clahe_vote']
order_CHO_images_blog4_test = ['CNN_all', 'Vgg16BN_pretrained', 'Vgg19BN_grey_covid', 'Vgg19BN_pretrained']
order_CHO_images_blog4_holdout = ['CNN_all', 'CNN_all_vote', 'Vgg16BN_pretrained', 'Vgg16BN_pretrained_vote', 'Vgg19BN_grey_covid', 'Vgg19BN_grey_covid_vote', 'Vgg19BN_pretrained', 'Vgg19BN_pretrained_vote']
order_CHO_images_blog5_test = copy.deepcopy(order_CHO_images_blog1_test)
order_CHO_images_blog5_test.extend(order_CHO_images_blog4_test[1:])
order_CHO_images_blog5_holdout = copy.deepcopy(order_CHO_images_blog1_holdout)
order_CHO_images_blog5_holdout.extend(order_CHO_images_blog4_holdout[2:])

# ####################################################################################################################

benchmark_synimages = 'synimages'
dataframes_synimages = [
    #"./dataframe_CNNMiniModel_synimages_blog1_30epochs_lr_01.csv",
    #"./dataframe_CNNModel_synimages_blog1_30epochs_lr_01.csv",
    #"./dataframe_ResNet18ModelLowerLayers_synimages_blog1_30epochs_lr_01.csv",
    #"./dataframe_ResNet18ModelAllLayers_synimages_blog1_30epochs_lr_01.csv",
    #"./dataframe_VggModelLowerLayers_synimages_blog1_30epochs_lr_01.csv",
    "./dataframe_VggModelAllLayers_synimages_blog1_30epochs_lr_01.csv",
    #"./dataframe_VggModelLowerLayers_synimages_centercrop_30epochs_lr_01.csv",
    #"./dataframe_VggModelLowerLayers_synimages_erode_30epochs_lr_01.csv",
    #"./dataframe_VggModelLowerLayers_synimages_tophat_mean_thresh_30epochs_lr_01.csv",
    #"./dataframe_VggModelLowerLayers_synimages_tophat_otsu_thresh_30epochs_lr_01.csv",
    #"./dataframe_VggModelLowerLayers_synimages_mean_thresh_sobel_30epochs_lr_01.csv",
    #"./dataframe_VggModelLowerLayers_synimages_otsu_thresh_sobel_30epochs_lr_01.csv",
    #"./dataframe_VggModelLowerLayers_synimages_clahe_30epochs_lr_01.csv",
    "./dataframe_Vgg19OneChannelModelAllLayersCovid19_synimages_withImageNet_15epochs_lr1e-3.csv",
    "./dataframe_Vgg19OneChannelModelAllLayersCovid19_synimages_withoutImageNet_20epochs_lr1e-3.csv",
    "./dataframe_Vgg19OneChannelModelAllLayers_synimages_withImageNet_15epochs_lr1e-5.csv",
    "./dataframe_Vgg19OneChannelModelAllLayers_synimages_withoutImageNet_15epochs_lr1e-5.csv",
    "./dataframe_Vgg19ThreeChannelModelAllLayersCovid19_synimages_withoutImageNet_15epochs_lr1e-3.csv",
    "./dataframe_Vgg19ThreeChannelModelAllLayersCovid19_synimages_withImageNet_15epochs_lr1e-3.csv",
    "./dataframe_Vgg19ThreeChannelModelAllLayers_synimages_withoutImageNet_15epochs_lr1e-3.csv",
    "./dataframe_Vgg19ThreeChannelModelAllLayers_synimages_withImageNet_15epochs_lr1e-3.csv",
    "./dataframe_CNNGreyModelCovid19_synimages__15epochs_lr1e-4.csv"
]
order_synimages_blog1_test = ['Vgg_all', 'Vgg_lower', 'ResNet_all', 'ResNet_lower', 'CNN_all', 'CNN_flat']
order_synimages_blog1_holdout = ['Vgg_all', 'Vgg_all_vote', 'Vgg_lower', 'Vgg_lower_vote', 'ResNet_all', 'ResNet_all_vote', 'ResNet_lower', 'ResNet_lower_vote', 'CNN_all', 'CNN_all_vote', 'CNN_flat', 'CNN_flat_vote']
order_synimages_blog2_test = ['Vgg_lower', 'erode', 'sobel_otsu', 'sobel_mean', 'tophat_otsu', 'tophat_mean', 'clahe']
order_synimages_blog2_holdout = ['Vgg_lower', 'Vgg_lower_vote', 'erode', 'erode_vote', 'sobel_otsu', 'sobel_otsu_vote', 'sobel_mean', 'sobel_mean_vote', 'tophat_otsu', 'tophat_otsu_vote', 'tophat_mean', 'tophat_mean_vote', 'clahe', 'clahe_vote']
order_synimages_blog3_test = ['Vgg_all', 'Vgg_lower', 'Vgg_lower_centercrop']
order_synimages_blog3_holdout = ['Vgg_all', 'Vgg_all_vote', 'Vgg_lower', 'Vgg_lower_vote', 'Vgg_lower_centercrop', 'Vgg_lower_centercrop_vote']
order_synimages_blog4_test = ['Vgg_lower', 'Vgg16BN_pretrained', 'Vgg19BN_grey_covid', 'Vgg19BN_pretrained']
order_synimages_blog4_holdout = ['Vgg_lower', 'Vgg_lower_vote', 'Vgg16BN_pretrained', 'Vgg16BN_pretrained_vote', 'Vgg19BN_grey_covid', 'Vgg19BN_grey_covid_vote', 'Vgg19BN_pretrained', 'Vgg19BN_pretrained_vote']
order_synimages_blog5_test = copy.deepcopy(order_synimages_blog1_test)
order_synimages_blog5_test.extend(order_synimages_blog4_test[1:])
order_synimages_blog5_holdout = copy.deepcopy(order_synimages_blog1_holdout)
order_synimages_blog5_holdout.extend(order_synimages_blog4_holdout[2:])

# ####################################################################################################################

benchmark_covid_mini = 'covid_mini'
dataframes_covid_mini = [
    #"./dataframe_CNNMiniModel_covid_mini_blog1.csv",
    #"./dataframe_CNNModel_covid_mini_blog1.csv",
    #"./dataframe_ResNet18ModelAllLayers_covid_mini_blog1.csv",
    #"./dataframe_ResNet18ModelLowerLayers_covid_mini_blog1.csv",
    #"./dataframe_VggModelAllLayers_covid_mini_blog1.csv",
    "./dataframe_VggModelLowerLayers_covid_mini_blog1.csv",
    #"./dataframe_VggModelLowerLayers_covid_mini_centercrop.csv",
    #"./dataframe_VggModelLowerLayers_covid_mini_randomcrop.csv",
    "./dataframe_VggModelLowerLayers_covid_mini_erode.csv",
    "./dataframe_VggModelLowerLayers_covid_mini_mean_thresh_sobel.csv",
    "./dataframe_VggModelLowerLayers_covid_mini_otsu_thresh_sobel.csv",
    "./dataframe_VggModelLowerLayers_covid_mini_tophat_otsu_thresh.csv",
    "./dataframe_VggModelLowerLayers_covid_mini_tophat_mean_thresh.csv",
    "./dataframe_VggModelLowerLayers_covid_mini_clahe.csv",
]
order_covid_mini_blog1_test = ['Vgg_all', 'Vgg_lower', 'Vgg_lower_centercrop']#, 'ResNet_all', 'ResNet_lower', 'CNN_all', 'CNN_flat']
order_covid_mini_blog1_holdout = ['Vgg_all', 'Vgg_all_vote', 'Vgg_lower', 'Vgg_lower_vote', 'Vgg_lower_centercrop', 'Vgg_lower_centercrop_vote']#'ResNet_all', 'ResNet_all_vote', 'ResNet_lower', 'ResNet_lower_vote', 'CNN_all', 'CNN_all_vote', 'CNN_flat', 'CNN_flat_vote']
order_covid_mini_blog2_test = ['Vgg_lower', 'erode', 'sobel_otsu', 'sobel_mean', 'tophat_otsu', 'tophat_mean', 'clahe']
order_covid_mini_blog2_holdout = ['Vgg_lower', 'Vgg_lower_vote', 'erode', 'erode_vote', 'sobel_otsu', 'sobel_otsu_vote', 'sobel_mean', 'sobel_mean_vote', 'tophat_otsu', 'tophat_otsu_vote', 'tophat_mean', 'tophat_mean_vote', 'clahe', 'clahe_vote']

# ####################################################################################################################

benchmark_covid_lungs = "covid_lungs_ct"
dataframes_covid_lungs = [
    #"./dataframe_CNNMiniModel_covid_lungs_ct_blog1_30epochs_lr_001.csv",
    #"./dataframe_CNNModel_covid_lungs_ct_blog1_30epochs_lr_001.csv",
    #"./dataframe_ResNet18ModelAllLayers_covid_lungs_ct_blog1_30epochs_lr_001.csv",
    #"./dataframe_ResNet18ModelLowerLayers_covid_lungs_ct_blog1_30epochs_lr_001.csv",
    "./dataframe_VggModelAllLayers_covid_lungs_ct_blog1_30epochs_lr_001.csv",
    #"./dataframe_VggModelLowerLayers_covid_lungs_ct_blog1_30epochs_lr_001.csv",
    #"./dataframe_VggModelLowerLayers_covid_lungs_ct_centercrop.csv",
    #"./dataframe_VggModelAllLayers_covid_lungs_ct_erode_30epochs_lr_001.csv",
    #"./dataframe_VggModelLowerLayers_covid_lungs_ct_LBP.csv",
    #"./dataframe_VggModelAllLayers_covid_lungs_ct_otsu_thresh_sobel_30epochs_lr_001.csv",
    #"./dataframe_VggModelAllLayers_covid_lungs_ct_mean_thresh_sobel_30epochs_lr_001.csv",
    #"./dataframe_VggModelAllLayers_covid_lungs_ct_tophat_otsu_thresh_30epochs_lr_001.csv",
    #"./dataframe_VggModelAllLayers_covid_lungs_ct_tophat_mean_thresh_30epochs_lr_001.csv",
    #"./dataframe_VggModelAllLayers_covid_lungs_ct_clahe_30epochs_lr_001.csv",
    "./dataframe_Vgg19OneChannelModelAllLayersCovid19_covid_lungs_ct_withImageNet_15epochs_lr1e-3.csv",
    "./dataframe_Vgg19OneChannelModelAllLayersCovid19_covid_lungs_ct_withoutImageNet_15epochs_lr1e-3.csv",
    "./dataframe_Vgg19OneChannelModelAllLayers_covid_lungs_ct_withImageNet_15epochs_lr1e-5.csv",
    "./dataframe_Vgg19OneChannelModelAllLayers_covid_lungs_ct_withoutImageNet_15epochs_lr1e-5.csv",
    "./dataframe_Vgg19ThreeChannelModelAllLayersCovid19_covid_lungs_ct_withoutImageNet_15epochs_lr1e-3.csv",
    "./dataframe_Vgg19ThreeChannelModelAllLayersCovid19_covid_lungs_ct_withImageNet_15epochs_lr1e-3.csv",
    "./dataframe_Vgg19ThreeChannelModelAllLayers_covid_lungs_ct_withImageNet_15epochs_lr1e-3.csv",
    "./dataframe_Vgg19ThreeChannelModelAllLayers_covid_lungs_ct_withoutImageNet_15epochs_lr1e-3.csv",
    "./dataframe_CNNGreyModelCovid19_covid_lungs_ct__15epochs_lr1e-4.csv"
]
order_covid_lungs_blog1_test = ['Vgg_all', 'Vgg_lower', 'ResNet_all', 'ResNet_lower', 'CNN_all', 'CNN_flat']
order_covid_lungs_blog1_holdout = ['Vgg_all', 'Vgg_all_vote', 'Vgg_lower', 'Vgg_lower_vote', 'ResNet_all', 'ResNet_all_vote', 'ResNet_lower', 'ResNet_lower_vote', 'CNN_all', 'CNN_all_vote', 'CNN_flat', 'CNN_flat_vote']
order_covid_lungs_blog2_test = ['Vgg_all', 'erode', 'sobel_otsu', 'sobel_mean', 'tophat_otsu', 'tophat_mean', 'clahe']
order_covid_lungs_blog2_holdout = ['Vgg_all', 'Vgg_all_vote', 'erode', 'erode_vote', 'sobel_otsu', 'sobel_otsu_vote', 'sobel_mean', 'sobel_mean_vote', 'tophat_otsu', 'tophat_otsu_vote', 'tophat_mean', 'tophat_mean_vote', 'clahe', 'clahe_vote']
order_covid_lungs_blog4_test = ['Vgg_lower', 'Vgg16BN_pretrained', 'Vgg19BN_grey_covid', 'Vgg19BN_pretrained']
order_covid_lungs_blog4_holdout = ['Vgg_lower', 'Vgg_lower_vote', 'Vgg16BN_pretrained', 'Vgg16BN_pretrained_vote', 'Vgg19BN_grey_covid', 'Vgg19BN_grey_covid_vote', 'Vgg19BN_pretrained', 'Vgg19BN_pretrained_vote']
order_covid_lungs_blog5_test = copy.deepcopy(order_covid_lungs_blog1_test)
order_covid_lungs_blog5_test.extend(order_covid_lungs_blog4_test[1:])
order_covid_lungs_blog5_holdout = copy.deepcopy(order_covid_lungs_blog1_holdout)
order_covid_lungs_blog5_holdout.extend(order_covid_lungs_blog4_holdout[2:])

# ####################################################################################################################

benchmark_WBC_segment = "blood_WBC_segmented"
dataframes_WBC_segment = [
    #"./dataframe_CNNMiniModel_blood_WBC_segmented_blog1_30epochs_lr_001.csv",
    #"./dataframe_CNNModel_blood_WBC_segmented_blog1_30epochs_lr_001.csv",
    #"./dataframe_ResNet18ModelAllLayers_blood_WBC_segmented_blog1_30epochs_lr_001.csv",
    #"./dataframe_ResNet18ModelLowerLayers_blood_WBC_segmented_blog1_30epochs_lr_001.csv",
    "./dataframe_VggModelAllLayers_blood_WBC_segmented_blog1_30epochs_lr_001.csv",
    #"./dataframe_VggModelLowerLayers_blood_WBC_segmented_blog1_30epochs_lr_001.csv",
    #"./dataframe_CNNModel_blood_WBC_segmented_erode_30epochs_lr_001.csv",
    #"./dataframe_CNNModel_blood_WBC_segmented_LBP.csv",
    #"./dataframe_CNNModel_blood_WBC_segmented_tophat_mean_thresh_30epochs_lr_001.csv",
    #"./dataframe_CNNModel_blood_WBC_segmented_tophat_otsu_thresh_30epochs_lr_001.csv",
    #"./dataframe_CNNModel_blood_WBC_segmented_mean_thresh_sobel_30epochs_lr_001.csv",
    #"./dataframe_CNNModel_blood_WBC_segmented_otsu_thresh_sobel_30epochs_lr_001.csv",
    #"./dataframe_CNNModel_blood_WBC_segmented_clahe_30epochs_lr_001.csv",
    #"./dataframe_CNNModel_blood_WBC_segmented_blog1_venn.csv",
    "./dataframe_Vgg19OneChannelModelAllLayersCovid19_blood_WBC_segmented_withImageNet_15epochs_lr1e-3.csv",
    "./dataframe_Vgg19OneChannelModelAllLayersCovid19_blood_WBC_segmented_withoutImageNet_15epochs_lr1e-3.csv",
    "./dataframe_Vgg19OneChannelModelAllLayers_blood_WBC_segmented_withImageNet_15epochs_lr1e-5.csv",
    "./dataframe_Vgg19OneChannelModelAllLayers_blood_WBC_segmented_withoutImageNet_15epochs_lr1e-5.csv",
    "./dataframe_Vgg19ThreeChannelModelAllLayersCovid19_blood_WBC_segmented_withoutImageNet_15epochs_lr1e-3.csv",
    "./dataframe_Vgg19ThreeChannelModelAllLayersCovid19_blood_WBC_segmented_withImageNet_15epochs_lr1e-3.csv",
    "./dataframe_Vgg19ThreeChannelModelAllLayers_blood_WBC_segmented_withImageNet_15epochs_lr1e-3.csv",
    "./dataframe_Vgg19ThreeChannelModelAllLayers_blood_WBC_segmented_withoutImageNet_15epochs_lr1e-3.csv",
    "./dataframe_CNNGreyModelCovid19_blood_WBC_segmented__15epochs_lr1e-4.csv"
    
]
order_WBC_segment_blog1_test = ['Vgg_all', 'Vgg_lower', 'ResNet_all', 'ResNet_lower', 'CNN_all', 'CNN_flat']
order_WBC_segment_blog1_holdout = ['Vgg_all', 'Vgg_all_vote', 'Vgg_lower', 'Vgg_lower_vote', 'ResNet_all', 'ResNet_all_vote', 'ResNet_lower', 'ResNet_lower_vote', 'CNN_all', 'CNN_all_vote', 'CNN_flat', 'CNN_flat_vote']
order_WBC_segment_blog2_test = ['CNN_all', 'erode', 'sobel_otsu', 'sobel_mean', 'tophat_otsu', 'tophat_mean', 'clahe']
order_WBC_segment_blog2_holdout = ['CNN_all', 'CNN_all_vote', 'erode', 'erode_vote', 'sobel_otsu', 'sobel_otsu_vote', 'sobel_mean', 'sobel_mean_vote', 'tophat_otsu', 'tophat_otsu_vote', 'tophat_mean', 'tophat_mean_vote', 'clahe', 'clahe_vote']
order_WBC_segment_blog4_test = ['CNN_all', 'Vgg16BN_pretrained', 'Vgg19BN_grey_covid', 'Vgg19BN_pretrained']
order_WBC_segment_blog4_holdout = ['CNN_all', 'CNN_all_vote', 'Vgg16BN_pretrained', 'Vgg16BN_pretrained_vote', 'Vgg19BN_grey_covid', 'Vgg19BN_grey_covid_vote', 'Vgg19BN_pretrained', 'Vgg19BN_pretrained_vote']
order_WBC_segment_blog5_test = copy.deepcopy(order_WBC_segment_blog1_test)
order_WBC_segment_blog5_test.extend(order_WBC_segment_blog4_test[1:])
order_WBC_segment_blog5_holdout = copy.deepcopy(order_WBC_segment_blog1_holdout)
order_WBC_segment_blog5_holdout.extend(order_WBC_segment_blog4_holdout[2:])

# ####################################################################################################################

benchmark_biomed_self = "biomed_self_label_shape"
dataframes_biomed_self  = [
                           "./dataframe_VggModelAllLayers_biomed_self_label_shape_blog1_vggfull.csv",
                            "./dataframe_VggModelLowerLayers_biomed_self_label_shape_blog1_vgglower.csv",
                            "./dataframe_ResNet18ModelAllLayers_biomed_self_label_shape_blog1_resnetfull.csv",
                            "./dataframe_ResNet18ModelLowerLayers_biomed_self_label_shape_blog1_resnetlower.csv",
                            "./dataframe_CNNModel_biomed_self_label_shape_blog1_cnnfull.csv",
                            "./dataframe_CNNMiniModel_biomed_self_label_shape_blog1_cnnmini.csv",
                            "./dataframe_CNNGreyModel_biomed_self_label_shape_blog1_cnngrey.csv",
    "./dataframe_VggModelAllLayers_biomed_self_label_shape_centercrop.csv",
    "./dataframe_VggModelAllLayers_biomed_self_label_shape_half_resize.csv",
    "./dataframe_VggModelAllLayers_biomed_self_label_shape_full_resize.csv",
    #"./dataframe_VggModelAllLayers_biomed_self_label_shape_randomcrop.csv" <---- some images too small
    "./dataframe_VggModelAllLayers_biomed_self_label_shape_LBP.csv",
    "./dataframe_VggModelAllLayers_biomed_self_label_shape_erode.csv",
    "./dataframe_VggModelAllLayers_biomed_self_label_shape_sobel_mean_adaptive_thresh.csv",
    "./dataframe_VggModelAllLayers_biomed_self_label_shape_tophat_mean_adaptive_thresh.csv",
    "./dataframe_VggModelAllLayers_biomed_self_label_shape_tophat_otsu_thresh.csv",
    "./dataframe_VggModelAllLayers_biomed_self_label_shape_sobel_otsu_thresh.csv"
]

# ####################################################################################################################
# SELECT THE EXPERIMENT BELOW, based on the settings above
# ####################################################################################################################

benchmark = benchmark_WBC_segment
dataframes = dataframes_WBC_segment
order_test = order_kaggle_bowl_blog6_test # or None
order_holdout = order_kaggle_bowl_blog6_holdout # or None

# %% [markdown]
# ### Run the code below to generate a graph for perfomance on the test sets for each model

# %%
import numpy as numpy
import pandas as pandas
import matplotlib.pyplot as plt  
import seaborn as sns
from mpl_toolkits.axes_grid1 import ImageGrid
import copy

# concat together all the csv files specified above
df = pandas.read_csv(download_dir + dataframes[0], header=None)
for d in dataframes[1:]:
    d = pandas.read_csv(download_dir + d, header=None)
    df = pandas.concat([df, d], axis=0)
df.columns = ['dataset', 'model', 'test_set', 'weighted average', 'time']
#print(df['model'].value_counts())

# generate the key of model names for display with the figure
model_names = list(set(list(df['model'])))
models = {}
ctr = 1
for m in model_names:
    models[m] = str(ctr)
    ctr += 1    
#print(models)

# cut the dataset down to just scores on the test sets
data_test = df[df['dataset'] == benchmark]
data_test = data_test[data_test['test_set'] == "test"]
data_test['full_label'] = copy.deepcopy(data_test['model'])
data_test['model'] = data_test['model'].apply(lambda x: models[x])

# print out the legend
labels = []
for k in models.keys():
    num = str(models[k])
    while len(num) < 4:
        num += ' '
    if 'voting' not in k:
        labels.append(num + " " + k)
        
        

#shorten the model name to display it in the chart (for blog posts)
def cleanName(raw):
    if 'Channel' in raw:
        if 'Three' in raw:
            if 'Covid19' in raw:
                if 'withImageNet' in raw:
                    if 'voting' in raw:
                        return 'Vgg19Color_COVID19_pretrained_vote'
                    else:
                        return 'Vgg19Color_COVID19_pretrained'
                elif 'withoutImageNet' in raw:
                    if 'voting' in raw:
                        return 'Vgg19Color_COVID19_vote'
                    else:
                        return 'Vgg19Color_COVID19'
            else:
                if 'withImageNet' in raw:
                    if 'voting' in raw:
                        return 'Vgg19Color_pretrained_vote'
                    else:
                        return 'Vgg19Color_pretrained'
                elif 'withoutImageNet' in raw:
                    if 'voting' in raw:
                        return 'Vgg19Color_vote'
                    else:
                        return 'Vgg19Color'
        elif 'One' in raw:
            if 'Covid19' in raw:
                if 'withImageNet' in raw:
                    if 'voting' in raw:
                        return 'Vgg19GreyCOVID19_pretrained_vote'
                    else:
                        return 'Vgg19GreyCOVID19_pretrained'
                elif 'withoutImageNet' in raw:
                    if 'voting' in raw:
                        return 'Vgg19GreyCOVID19_vote'
                    else:
                        return 'Vgg19GreyCOVID19'
            else:
                if 'withImageNet' in raw:
                    if 'voting' in raw:
                        return 'Vgg19COVID19_pretrained_vote'
                    else:
                        return 'Vgg19COVID19_pretrained'
                elif 'withoutImageNet' in raw:
                    if 'voting' in raw:
                        return 'Vgg19COVID19_vote'
                    else:
                        return 'Vgg19COVID19'
    elif 'Covid19' in raw and 'Grey' in raw:
        if 'voting' in raw:
            return 'CNNGrey_COVID19_vote'
        else:
            return 'CNNGrey_COVID19'
  
    elif 'Vgg19' in raw:
        if 'Covid19' in raw:
            if 'voting' in raw:
                return 'Vgg19BN_grey_covid_vote'
            else:
                return 'Vgg19BN_grey_covid'
    elif 'venn' in raw:
        if 'voting' in raw:
            return 'CNN_venn_vote'
        return 'CNN_venn'
    elif 'tophat_mean' in raw:
        if 'voting' in raw:
            return 'tophat_mean_vote'
        return 'tophat_mean'
    elif 'tophat_otsu' in raw:
        if 'voting' in raw:
            return 'tophat_otsu_vote'
        return 'tophat_otsu'
    elif 'otsu_thresh_sobel' in raw:
        if 'voting' in raw:
            return 'sobel_otsu_vote'
        return 'sobel_otsu'
    elif 'mean_thresh_sobel' in raw:
        if 'voting' in raw:
            return 'sobel_mean_vote'
        return 'sobel_mean'
    elif 'erode' in raw or "erosion" in raw:
        if 'voting' in raw:
            return 'erode_vote'
        return 'erode'
    elif 'clahe' in raw:
        if 'voting' in raw:
            return 'clahe_vote'
        return 'clahe'
    elif 'CNNMini' in raw:
        if 'voting' in raw:
            return 'CNN_flat_vote'
        return 'CNN_flat'
    elif "fullsize" in raw:
        if 'voting' in raw:
            return 'CNN_large_image_vote'
        return "CNN_large_image"
    elif 'CNN' in raw:
        if 'voting' in raw:
            return 'CNN_all_vote'
        return 'CNN_all'
    elif 'VggModelLowerLayers' in raw:
        if 'voting' in raw:
            if 'centercrop' in raw:
                return 'Vgg_lower_centercrop_vote'
            else:
                return 'Vgg_lower_vote'
        if 'centercrop' in raw:
            return 'Vgg_lower_centercrop'
        return 'Vgg_lower'
    elif 'Vgg16BN' in raw:
        if 'voting' in raw:
            return 'Vgg16BN_pretrained_vote'
        return 'Vgg16BN_pretrained'
    elif 'Vgg' in raw:
        if 'voting' in raw:
            return 'Vgg_all_vote'
        return 'Vgg_all'
    elif 'ResNet18ModelLowerLayers' in raw:
        if 'voting' in raw:
            return 'ResNet_lower_vote'
        return 'ResNet_lower'
    elif 'ResNet' in raw:
        if 'voting' in raw:
            return 'ResNet_all_vote'
        return 'ResNet_all'
    return 'ERROR'
        
print("results for each test set")
plt.figure(figsize=(20,5))
if order_test == None:
    for i in sorted(labels):
        print(i)
    sns.boxplot(
        data=data_test,
        x='model',
        y='weighted average')
else:
    print(data_test['full_label'].value_counts())
    print(data_test[data_test['full_label'] == 'VggGreyCOVID19'].head(40))
    data_test['model'] = data_test['full_label'].apply(lambda x: cleanName(x))
    sns.boxplot(
        data=data_test,
        x='model',
        y='weighted average',
        order=order_test)

plt.show()
# Out:
# results for each test set
# VggModelAllLayers_blood_WBC_segmented_blog1                                   20
# Vgg19ThreeChannelModelAllLayersCovid19_blood_WBC_segmented_withoutImageNet    20
# CNNGreyModelCovid19_blood_WBC_segmented_                                      20
# Vgg19OneChannelModelAllLayers_blood_WBC_segmented_withoutImageNet             20
# Vgg19ThreeChannelModelAllLayers_blood_WBC_segmented_withImageNet              20
# Vgg19ThreeChannelModelAllLayers_blood_WBC_segmented_withoutImageNet           20
# Vgg19OneChannelModelAllLayers_blood_WBC_segmented_withImageNet                20
# Vgg19ThreeChannelModelAllLayersCovid19_blood_WBC_segmented_withImageNet       20
# Vgg19OneChannelModelAllLayersCovid19_blood_WBC_segmented_withoutImageNet      20
# Vgg19OneChannelModelAllLayersCovid19_blood_WBC_segmented_withImageNet         20
# Name: full_label, dtype: int64
# Empty DataFrame
# Columns: [dataset, model, test_set, weighted average, time, full_label]
# Index: []

# %% [markdown]
# ### Run the code below to generate a graph for the performance of each model, and its respective voting ensemble version, on the holdout test set

# %%
# cut the dataframe to just the holdout and voting results
data_holdout = df[df['dataset'] == benchmark]
data_holdout = data_holdout[data_holdout['test_set'] == "holdout"]

# generate the key for this figure (includes voting algs not included in figure above)
model_strings = list(data_holdout['model'])
cleaned_strings = [model_strings[0]]
ctr = 1
while ctr < len(model_strings):
    if model_strings[ctr] not in cleaned_strings:
        cleaned_strings.append(model_strings[ctr])
    ctr += 1
models = {}
ctr = 1
for i in cleaned_strings:
    if i not in models.keys():
        models[i] = ctr
    ctr += 1
data_holdout['full_label'] = copy.deepcopy(data_holdout['model'])
data_holdout['model'] = data_holdout['model'].apply(lambda x: models[x])
        
# print out the legend
labels = []
for k in models.keys():
    num = str(models[k])
    while len(num) < 4:
        num += ' '
    if 'voting' in k:
        labels.append(num + " " + k)
def numerize(x):
    return int(x.split(" ")[0])
    
print("results for the holdout dataset")
plt.figure(figsize=(20,5))

if order_holdout == None:
    for i in sorted(labels, key=numerize):
        print(i)
    sns.boxplot(
        data=data_holdout,
        x='model',
        y='weighted average')
    plt.show()
else:
    data_holdout['model'] = data_holdout['full_label'].apply(lambda x: cleanName(x))
    sns.boxplot(
        data=data_holdout,
        x='model',
        y='weighted average',
        order=order_holdout)
# Out:
# results for the holdout dataset

# %% [markdown]
# ### Display the learning curves for various experiments and models

# %%
epochs = "50"
lr = "001" 
dataset = 'covid_lungs_ct'
df_list_kaggle = [
'CNNMiniModel_' + dataset + '_blog1_' + epochs + 'epochs_lr_' + lr + '.curve',
'CNNModel_' + dataset + '_blog1_' + epochs + 'epochs_lr_' + lr + '.curve',
'ResNet18ModelAllLayers_' + dataset + '_blog1_' + epochs + 'epochs_lr_' + lr + '.curve',
'ResNet18ModelLowerLayers_' + dataset + '_blog1_' + epochs + 'epochs_lr_' + lr + '.curve',
'Vgg16BNThreeChannelModelAllLayers_' + dataset + '_blog1_' + epochs + 'epochs_lr_' + lr + '.curve',
'Vgg19ThreeChannelModelAllLayers_' + dataset + '_blog1_' + epochs + 'epochs_lr_' + lr + '.curve',
'VggModelAllLayers_' + dataset + '_blog1_' + epochs + 'epochs_lr_' + lr + '.curve',
'VggModelLowerLayers_' + dataset + '_blog1_' + epochs + 'epochs_lr_' + lr + '.curve',
'Vgg19OneChannelModelAllLayersCovid19_' + dataset + '_blog1_' + epochs + 'epochs_lr_' + lr + '.curve'
]

df_list = df_list_kaggle

for file in df_list:
    curve = pandas.read_csv('/Users/kdobolyi/Downloads/curve/' + file)

    # Get training and test loss histories
    training_loss = curve['training_loss']
    test_loss = curve['weighted_accuracy_train']

    # Create count of the number of epochs
    epoch_count = range(1, len(training_loss) + 1)

    # Visualize loss history
    plt.plot(epoch_count, training_loss, 'r--')
    plt.plot(epoch_count, test_loss, 'b-')
    title = file
    plt.title(title)
    plt.legend(['Training Loss', 'Training weighted accuracy'])
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.show()
